# %% [markdown]
# # List and Tuples
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 6.1 Prime Number Checker
# Create a program that checks whether a number is a prime number and displays its factors if it is not a prime number.
#
# ### Console:
# ```powershell
# Prime Number Checker
#
# Please enter an integer between 1 and 5000: 5
# 5 is a prime number.
#
# Try again? (y/n): y
#
# Please enter an integer between 1 and 5000: 6
# 6 is NOT a prime number.
# It has 4 factors: 1 2 3 6
#
# Try again? (y/n): y
#
# Please enter an integer between 1 and 5000: 200
# 200 is NOT a prime number.
# It has 12 factors: 1 2 4 5 8 10 20 25 40 50 100 200
#
# Try again? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - A prime number is divisible by two factors (1 and itself). For example, 7 is a prime number because it is only divisible by 1 and 7.
# - If the user enters an integer that's not between 1 and 5000, the program should display an error message.
# - If the number is a prime number, the program should display a message.
# If the number is not a prime number, the program should display a message. Then, it should display the number of factors for the number and a list of those factors.
# - Store the factors for each number in a list.
# - Use functions to organize the code for this program.

# %%
def get_int():
    while True:
        num = int(input("Please enter an integer between 1 and 5000: "))
        if 1 < num < 5000:
            return num
        else:
            print("Invalid Integer, Please input a integer between 1 and 5000")

def get_factors(num):
    count = []
    for i in range(1, num + 1):
        temp = []
        if num % i == 0:
            count.append(i)
    return count

def main():
    print("Prime Number Checker\n")
    
    choice = "y"
    while choice.lower() == "y":
        number = get_int()
        factors = get_factors(number)

        if len(factors) == 2:
            print(number, "is a prime number")
        else:
            print(number, "is NOT a prime number.\nIt has", len(factors), "factors: ", factors )
        
        choice = input("\nTry again? (y/n):")
        print()

    print("Bye!")

if __name__ == "__main__":
    main()
# Out:
# Prime Number Checker
# Please enter an integer between 1 and 5000:  5
# 5 is a prime number
# Try again? (y/n): y
# Please enter an integer between 1 and 5000:  6
# 6 is NOT a prime number.
# It has 4 factors:  [1, 2, 3, 6]
# Try again? (y/n): y
# Please enter an integer between 1 and 5000:  200
# 200 is NOT a prime number.
# It has 12 factors:  [1, 2, 4, 5, 8, 10, 20, 25, 40, 50, 100, 200]
# Try again? (y/n): n
# Thanks, bye!

# %% [markdown]
# ## 6.2 - Contact Manager
# Create a program that a user can use to manage the primary email address and phone number for a contact.
#
# ### Console
# ```powershell
# Contact Manager
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# del - Delete a contact
# exit - Exit program
#
# Command: list
# 1. Guido van Rossum
# 2. Eric Idle
#
# Command: view
# Number: 2
# Name: Eric Idle
# Email: eric@ericidle.com
# Phone: +44 20 7946 0958
#
# Command: add
# Name: Mike Murach
# Email: mike@murach.com
# Phone: 559-123-4567
# Mike Murach was added.
#
# Command: del
# Number: 1
# Guido van Rossum was deleted.
#
# Command: list
# 1. Eric Idle
# 2. Mike Murach
#
# Command: exit
# Bye!
# ```
#
# ### Specifications:
# - Use a list of lists to store the data for the contacts. Provide starting data for two or more contacts.
# - For the `view` and `del` commands, display an error message if the user enters and invalid contact number.
# - When you exit the program, all changes that you made to the contact list are lost.

# %%
def display_menu():
    print("COMMAND MENU")
    print("list - Display all contacts")
    print("view - View a contact")
    print("add - Add a contact")
    print("del - Delete a contact")
    print("exit - Exit program\n")

def list(email_list):
    i = 1
    for row in email_list:
        contact_info = row[0]
        print(str(i), ". ", contact_info)
        i += 1
    print()

def add(email_list):
    name = input("Name: ")
    email = input("Email: ")
    phone = input("Phone: ")
    emails = []
    emails.append(name)
    emails.append(email)
    emails.append(phone)
    email_list.append(emails)
    print(name, " was added\n")

def view(email_list):
    number = int(input("Number: "))
    if number < 1 or number > len(email_list):
        print("Invalid Email Number")
    else:
        email = email_list[number - 1]
        print("Name: ", email[0])
        print("Email: ", email[1])
        print("Phone: ", email[2])
        print()

def delete(email_list):
    number = int(input("Number: "))
    if number < 1 or number > len(email_list):
        print("Invalid Email Number")
    else:
        email = email_list.pop(number - 1)
        print(email[0], " was deleted\n")
        
def main():
    email_list = [["Guido van Rossum", "guido@guidovanrossum.com", "+44 20 7946 0967"], 
                  ["Eric Idle", "eric@ericidle.com", "+44 20 7946 0958"]]

    print("Contact Manager\n")
    display_menu()

    while True:        
        command = input("Command: ")
        if command == "list":
            list(email_list)
        elif command == "add":
            add(email_list)
        elif command == "del":
            delete(email_list)
        elif command == "view":
            view(email_list)    
        elif command == "exit":
            break
        else:
            print("Not a valid command. Please try again.\n")
    print("Bye!")

if __name__ == "__main__":
    main()
# Out:
# Contact Manager
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# del - Delete a contact
# exit - Exit program
# Command:  list
# 1 .  Guido van Rossum
# 2 .  Eric Idle
# Command:  view
# Number:  1
# Name:  Guido van Rossum
# Email:  guido@guidovanrossum.com
# Phone:  +44 20 7946 0967
# Command:  exit
# Bye!
