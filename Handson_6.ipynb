# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
def read_champions(filename):
    champions = {}
    with open(filename, "r") as file:
        lines = file.readlines()
    for i in range(1, len(lines)):
        line = lines[i]
        line = line.replace("\n", "")
        data = line.split(",")

        year = data[0]
        country = data[1]

        if country in champions:
            champions[country].append(year)
        else:
            champions[country] = [year]
            
    return champions

def display_champions(champions):
    print("Country\t\tWins\tYears")
    print("=======\t\t====\t=====")

    countries = list(champions.keys())
    countries.sort()

    for country in countries:
        years_list = champions[country]
        wins = str(len(years_list))
        years = ""
        
        for y in years_list:
            years += y + ", "
        years = years[:-2]
        
        if len(country) > 7:
            print(country + "\t" + wins + "\t" + years)
        else:
            print(country + "\t\t" + wins + "\t" + years)

def main():
    filename = "world_cup_champions.txt"
    champions = read_champions(filename)
    display_champions(champions)

if __name__ == "__main__":
    main()
# Out:
# Country		Wins	Years
# =======		====	=====
# Argentina	2	1978, 1986
# Brazil		5	1958, 1962, 1970, 1994, 2002
# England		1	1966
# France		1	1998
# Germany		4	1954, 1974, 1990, 2014
# Italy		4	1934, 1938, 1982, 2006
# Spain		1	2010
# Uruguay		2	1930, 1950

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
def read_sales_file(filename):
    sales_data = {}
    
    with open(filename, "r") as file:
        lines = file.readlines()
        
    for line in lines:
        line = line.replace("\n", "")
        data = line.split("\t")

        month = data[0].title()
        amount = int(data[1])
        
        sales_data[month] = amount

    return sales_data

def write_sales_data(sales_data, filename):
    with open(filename, "w") as file:
        for month, amount in sales_data.items():
            file.write(month + "\t" + str(amount) + "\n")

def display_menu():
    print("COMMAND MENU")
    print("view - View sales for specified month")
    print("edit - Edit sales for specified month")
    print("totals - View sales summary for year")
    print("exit - Exit program\n")

def main():
    filename = "monthly_sales.txt"

    print("Monthly Sales Program\n")
    display_menu()

    sales = read_sales_file(filename)

    while True:
        command = input("Command: ").lower()
        
        if command == "view":
            month = input("Three-letter Month: ").title()
            
            if month in sales:
                print("Sales amount for " + month + " is " + str(sales[month]) + ".\n")
            else:
                print("Invalid three-letter input.\n")
                
        elif command == "edit":
            month = input("Three-letter Month: ").title()
            
            if month in sales:
                new_amount = int(input("Sales Amount: "))
                
                sales[month] = new_amount
                write_sales_data(sales, filename)
                
                print("Sales amount for " + month + " is " + str(sales[month]) + ".\n")
            else:
                print("Invalid three-letter input.\n")
                
        elif command == "totals":
            total = 0
            for amount in sales.values():
                total += amount
                
            monthly_avg = total / len(sales)
            
            monthly_avg = round(monthly_avg, 2)
            
            print("Yearly Total: " + str(total))
            print("Monthly Average: " + str(monthly_avg) + "\n")
            
        elif command == "exit":
            print("Bye!")
            break
            
        else:
            print("Invalid command. Please try again.\n")
            
if __name__ == "__main__":
    main()
# Out:
# Monthly Sales Program
#
# COMMAND MENU
# view - View sales for specified month
# edit - Edit sales for specified month
# totals - View sales summary for year
# exit - Exit program
# Command:  view
# Three-letter Month:  jan
# Sales amount for Jan is 14317.
# Command:  edit
# Three-letter Month:  jan
# Sales Amount:  15293
# Sales amount for Jan is 15293.
# Command:  totals
# Yearly Total: 67855
# Monthly Average: 5654.58
# Command:  view
# Three-letter Month:  july
# Invalid three-letter input.
# Command:  exit
# Bye!
